# %%
import numpy as np
import pandas as pd
import quandl
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
seekingalpha = pd.read_csv('seekingalpha_proj_final.csv')

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
for i in range(23577):
    try:
        seekingalpha.Plus180Days[i] = seekingalpha.Plus180Days[i][:10]
    except:
        seekingalpha.Plus180Days[i] = ''
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
seekingalpha.to_csv('SA1.csv')

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
quandl.ApiConfig.api_key = 'qXwFzCcC3GXAuCMzthq4'
for i in np.arange(5000):
    try:
        seekingalpha.Plus180Price[i] = quandl.get_table('WIKI/PRICES', date=seekingalpha.Plus180Days[i], ticker=seekingalpha.Ticker[i])['close'][0]
    except:
        seekingalpha.Plus180Price[i] = print('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
quandl.ApiConfig.api_key = 'qXwFzCcC3GXAuCMzthq4'
for i in np.arange(5000,10000):
    try:
        seekingalpha.Plus180Price[i] = quandl.get_table('WIKI/PRICES', date=seekingalpha.Plus180Days[i], ticker=seekingalpha.Ticker[i])['close'][0]
    except:
        seekingalpha.Plus180Price[i] = print('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
seekingalpha.to_csv('SA1.csv')

# %%
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
seekingalpha['Day30Movement'] = ''

# %%
seekingalpha['Day180Movement'] = ''

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
quandl.ApiConfig.api_key = 'qXwFzCcC3GXAuCMzthq4'
for i in np.arange(10000,15000):
    try:
        seekingalpha.Plus180Price[i] = quandl.get_table('WIKI/PRICES', date=seekingalpha.Plus180Days[i], ticker=seekingalpha.Ticker[i])['close'][0]
    except:
        seekingalpha.Plus180Price[i] = print('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
quandl.ApiConfig.api_key = 'qXwFzCcC3GXAuCMzthq4'
for i in np.arange(21000,23577):
    try:
        seekingalpha.Plus180Price[i] = quandl.get_table('WIKI/PRICES', date=seekingalpha.Plus180Days[i], ticker=seekingalpha.Ticker[i])['close'][0]
    except:
        seekingalpha.Plus180Price[i] = print('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
seekingalpha.to_csv('SA1.csv')

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
for i in np.arange(21000,23577):
    try:
        seekingalpha.Day30Movement[i] = ((seekingalpha.Plus30Price[i] - seekingalpha.PostDatePrice[i])/seekingalpha.PostDatePrice[i])*100
    except:
        seekingalpha.Day30Movement[i] = print ('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in np.arange(21000,23577):
    try:
        seekingalpha.Day180Movement[i] = ((seekingalpha.Plus180Price[i] - seekingalpha.PostDatePrice[i])/seekingalpha.PostDatePrice[i])*100
    except:
        seekingalpha.Day180Movement[i] = print ('')
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
seekingalpha.to_csv('SA1.csv')

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
seekingalpha.groupby(['Month','Year'])['Ticker'].agg('count').plot.line()

# %%
seekingalpha.groupby(['Month','Year','Ticker'])['Ticker'].agg('count').sort_values(ascending = False)
# Out:
# Month  Year  Ticker
# 4.0    2013  AAPL      39
# 11.0   2012  AAPL      34
# 12.0   2012  AAPL      34
# 10.0   2012  AAPL      32
# 1.0    2013  AAPL      28
# 3.0    2013  AAPL      28
# 10.0   2013  AAPL      23
# 9.0    2013  AAPL      22
# 2.0    2013  AAPL      22
# 7.0    2017  BA        22
# 5.0    2013  AAPL      19
# 4.0    2014  AAPL      19
# 1.0    2017  BA        17
# 10.0   2013  AMZN      17
# 9.0    2017  BA        16
# 7.0    2016  AAPL      15
# 9.0    2014  AAPL      15
# 12.0   2013  AAPL      15
# 7.0    2016  BA        14
# 3.0    2013  BB        14
# 11.0   2015  VRX       14
# 5.0    2017  BA        14
# 12.0   2016  AAPL      13
# 3.0    2016  VRX       13
# 6.0    2017  AAPL      13
# 1.0    2014  AAPL      13
# 11.0   2012  MSFT      12
# 8.0    2017  BA        12
# 10.0   2013  MSFT      12
#        2012  BAC       12
#                        ..
# 11.0   2015  BB         1
#              BBW        1
# 7.0    2016  BHP        1
# ...

# %%
seekingalpha.groupby(['Year','Author'])['Author'].agg('count').sort_values(ascending = False)
# Out:
# Year  Author
# 2014  Benjamin Clark                    253
# 2015  Benjamin Clark                    231
# 2014  The Value Investor                218
# 2013  Bret Jensen                       181
#       Zacks Investment Research         180
#       The Value Investor                164
# 2017  Zach Hartman, PhD                 161
# 2015  Spencer Osborne                   157
# 2014  Zacks Investment Research         150
# 2016  Achilles Research                 140
# 2015  The Value Investor                140
# 2013  Nick Chiu                         132
# 2016  Spencer Osborne                   128
# 2014  Joseph Cafariello                 122
# 2017  Dhierin Bechai                    117
# 2013  Kapitall                          116
# 2014  Stock Traders Daily               111
# 2016  Vladimir Zernov                   110
# 2015  Dallas Salazar                    109
# 2014  Bret Jensen                       108
# 2015  Dana Blankenhorn                  107
# ...

# %%
sns.kdeplot(seekingalpha['Year'], shade=True, label='Website Usage')

# %%
sns.distplot(seekingalpha['Year'])

# %%
seekingalpha.groupby(['Year'])['Day30Movement']

# %%
sns.boxplot(x='Year', y='Month', data=seeking)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-8add1508faac> in <module>()
# ----> 1 sns.boxplot(x='Year', y='Month', data=monthly_count)
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
# ...

# %%
AuthorGrid = Author_count.FacetGrid(tips, col='Month', hue='Author', palette="Year", size=4)
AuthorGrid.map(Author_count.distplot, "tip")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-b14a0d4007c4> in <module>()
# ----> 1 AuthorGrid = Author_count.FacetGrid(tips, col='Month', hue='Author', palette="Year", size=4)
#       2 AuthorGrid.map(Author_count.distplot, "tips")
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'FacetGrid'

# %%
seekingalpha.to_csv('SA1.csv')

# %%
seekingalpha.groupby(['Ticker','Day180Movement'])['Day180Movement'].max()
# Out:
# Ticker  Day180Movement
# A        0.671378         0.671378
#          1.674859          1.67486
#          4.510341          4.51034
#          30.950324         30.9503
# AAL     -17.889344        -17.8893
#         -16.229282        -16.2293
#         -15.590200        -15.5902
#         -15.458015         -15.458
#         -12.418575        -12.4186
#         -9.624537         -9.62454
#         -7.155681         -7.15568
#         -7.106868         -7.10687
#         -4.335729         -4.33573
#         -1.763164         -1.76316
#         -1.564440         -1.56444
#         -0.577234        -0.577234
#         -0.534138        -0.534138
#         -0.400283        -0.400283
#          2.438424          2.43842
#          5.965574          5.96557
#          11.452729         11.4527
#          13.232748         13.2327
#          18.107833         18.1078
#          20.174129         20.1741
#          21.069032          21.069
#          25.215089         25.2151
# ...

# %%
seekingalpha.grou
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
dropalpha = seekingalpha.dropna()

# %%
dropalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 1873         1873          1873  Wed, Apr. 19,
# 1874         1874          1874  Wed, Apr. 19,
# 1875         1875          1875  Wed, Apr. 19,
# 1876         1876          1876  Wed, Apr. 19,
# 1877         1877          1877  Wed, Apr. 19,
# 1881         1881          1881  Wed, Apr. 19,
# 1883         1883          1883  Wed, Apr. 19,
# 1886         1886          1886  Wed, Apr. 19,
# 1887         1887          1887  Wed, Apr. 19,
# 1888         1888          1888  Wed, Apr. 19,
# 1889         1889          1889  Wed, Apr. 19,
# 1961         1961          1961  Wed, Apr. 12,
# 1962         1962          1962  Wed, Apr. 12,
# 1963         1963          1963  Wed, Apr. 12,
# 1964         1964          1964  Wed, Apr. 12,
# 1967         1967          1967  Wed, Apr. 12,
# 1968         1968          1968  Wed, Apr. 12,
# 1969         1969          1969  Wed, Apr. 12,
# 2060         2060          2060   Wed, Apr. 5,
# ...

# %%
perfect30 = seekingalpha.dropna(subset = ['Day30Movement'])

# %%
perfect30
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 500           500           500  Mon, Aug. 21,
# 502           502           502  Mon, Aug. 21,
# 503           503           503  Mon, Aug. 21,
# 506           506           506  Mon, Aug. 21,
# 507           507           507  Mon, Aug. 21,
# 508           508           508  Mon, Aug. 21,
# 509           509           509  Mon, Aug. 21,
# 511           511           511  Mon, Aug. 21,
# 513           513           513  Mon, Aug. 21,
# 514           514           514  Mon, Aug. 21,
# 516           516           516  Mon, Aug. 21,
# 517           517           517  Mon, Aug. 21,
# 518           518           518  Mon, Aug. 21,
# 521           521           521  Mon, Aug. 21,
# 522           522           522  Mon, Aug. 21,
# 562           562           562  Wed, Aug. 16,
# 569           569           569  Wed, Aug. 16,
# 570           570           570  Wed, Aug. 16,
# 572           572           572  Wed, Aug. 16,
# ...

# %%
perfect180 = seekingalpha.dropna(subset = ['Day180Movement'])

# %%
perfect180
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 1847         1847          1847  Fri, Apr. 21,
# 1848         1848          1848  Fri, Apr. 21,
# 1849         1849          1849  Fri, Apr. 21,
# 1852         1852          1852  Fri, Apr. 21,
# 1856         1856          1856  Fri, Apr. 21,
# 1857         1857          1857  Fri, Apr. 21,
# 1858         1858          1858  Thu, Apr. 20,
# 1860         1860          1860  Thu, Apr. 20,
# 1861         1861          1861  Thu, Apr. 20,
# 1863         1863          1863  Thu, Apr. 20,
# 1864         1864          1864  Thu, Apr. 20,
# 1867         1867          1867  Thu, Apr. 20,
# 1868         1868          1868  Thu, Apr. 20,
# 1869         1869          1869  Thu, Apr. 20,
# 1870         1870          1870  Thu, Apr. 20,
# 1871         1871          1871  Thu, Apr. 20,
# 1873         1873          1873  Wed, Apr. 19,
# 1874         1874          1874  Wed, Apr. 19,
# 1875         1875          1875  Wed, Apr. 19,
# ...

# %%
seekingalpha
# Out:
#        Unnamed: 0  Unnamed: 0.1           Date  \
# 0               0             0  Oct. 18, 2017
# 1               1             1  Oct. 18, 2017
# 2               2             2  Oct. 18, 2017
# 3               3             3  Oct. 18, 2017
# 4               4             4              •
# 5               5             5  Oct. 18, 2017
# 6               6             6  Oct. 18, 2017
# 7               7             7  Oct. 18, 2017
# 8               8             8  Oct. 18, 2017
# 9               9             9  Oct. 17, 2017
# 10             10            10  Oct. 17, 2017
# 11             11            11  Oct. 17, 2017
# 12             12            12  Oct. 17, 2017
# 13             13            13  Oct. 17, 2017
# 14             14            14  Oct. 17, 2017
# 15             15            15  Oct. 17, 2017
# 16             16            16  Oct. 17, 2017
# 17             17            17  Oct. 17, 2017
# 18             18            18  Oct. 17, 2017
# ...

# %%
top5_author_count = seekingalpha.groupby(['Year','Author'], as_index = False)['Title'].agg('count').sort_values(['Year','Title'],ascending = False).groupby('Year').head(10)

# %%
perfect30.Day30Movement = abs(perfect30.Day30Movement)
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
perfect180.Day180Movement = abs(perfect180.Day180Movement)
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
Month_breakdown = seekingalpha.groupby(['Year','Month'], as_index = False)['Date'].agg('count')

# %%
pd.DataFrame(Month_breakdown).reset_index()
# Out:
#     Year  Month  Date
# 0   2012   10.0   500
# 1   2012   11.0   600
# 2   2012   12.0   526
# 3   2013    1.0   407
# 4   2013    2.0   509
# 5   2013    3.0   591
# 6   2013    4.0   549
# 7   2013    5.0   399
# 8   2013    7.0   101
# 9   2013    8.0   338
# 10  2013    9.0   383
# 11  2013   10.0   465
# 12  2013   11.0   357
# 13  2013   12.0   346
# 14  2014    1.0   347
# 15  2014    2.0   357
# 16  2014    3.0   359
# 17  2014    4.0   313
# 18  2014    5.0   199
# 19  2014    6.0   351
# 20  2014    7.0   106
# 21  2014    8.0   338
# 22  2014    9.0   449
# 23  2014   10.0   458
# 24  2014   11.0   399
# 25  2014   12.0   366
# 26  2015    1.0   539
# 27  2015    2.0   551
# 28  2015    3.0   628
# 29  2015    4.0   620
# 30  2015    5.0   501
# 31  2015    6.0   419
# 32  2015    7.0   527
# 33  2015    8.0   446
# 34  2015    9.0   435
# 35  2015   10.0   313
# 36  2015   11.0   487
# 37  2015   12.0   435
# 38  2016    1.0   395
# 39  2016    2.0   296
# ...

# %%
Month_breakdown
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bc7ffbf5b5c4> in <module>()
# ----> 1 Month_breakdown
#
# NameError: name 'Month_breakdown' is not defined

# %%
plt.plot(list(Month_breakdown.index),Month_breakdown.Date)

# %%
perfect30.groupby(['Year','Author']).Day30Movement.mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-401-7f291e357a61> in <module>()
# ----> 1 perfect30.groupby(['Year','Author']).Day30Movement.mean()
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in mean(self, *args, **kwargs)
#    1035         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1036         try:
# -> 1037             return self._cython_agg_general('mean', **kwargs)
#    1038         except GroupByError:
#    1039             raise
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_agg_general(self, how, alt, numeric_only)
#     834
#     835         if len(output) == 0:
# --> 836             raise DataError('No numeric types to aggregate')
#     837
#     838         return self._wrap_aggregated_output(output, names)
#
# ...

# %%
perfect30.Day30Movement = perfect30.Day30Movement.astype(float)
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
top5_30Day = perfect30.groupby(['Year','Author'],as_index = False).Day30Movement.mean().sort_values(['Year','Day30Movement'], ascending = False).groupby('Year').head(10)

# %%
top5_30Day
# Out:
#       Year                          Author  Day30Movement
# 2472  2017              Slingshot Insights      53.184504
# 2202  2017                    Adam Alvarez      37.032967
# 2308  2017                     Fun Trading      34.422814
# 2315  2017                   George Putnam      33.447293
# 2309  2017       FundamentalSpeculation.IO      30.790960
# 2476  2017                 Spencer Osborne      30.337381
# 2405  2017              Mary Jane Fountain      23.214286
# 2407  2017                      Matt Hogan      23.123439
# 2257  2017                   Colin Ferrian      22.635135
# 2263  2017                     DX2 Capital      22.303082
# 1805  2016              DiligentBiotechGuy      72.868217
# 2169  2016             Value On The Street      54.666667
# 2171  2016              ValueChaseResearch      47.770701
# 2137  2016            The Technical Trader      46.529563
# 2158  2016                     Trent Welsh      45.638361
# ...

# %%
top5_author_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b77d4f482958> in <module>()
# ----> 1 top5_author_count
#
# NameError: name 'top5_author_count' is not defined

# %%
pd.merge(top5_30Day, top5_author_count, on='Author', how='left', indicator=True)
# Out:
#     Year_x                          Author  Day30Movement  Year_y  Title  \
# 0     2017              Slingshot Insights      53.184504     NaN    NaN
# 1     2017                    Adam Alvarez      37.032967     NaN    NaN
# 2     2017                     Fun Trading      34.422814     NaN    NaN
# 3     2017                   George Putnam      33.447293     NaN    NaN
# 4     2017       FundamentalSpeculation.IO      30.790960     NaN    NaN
# 5     2017                 Spencer Osborne      30.337381  2017.0   57.0
# 6     2017                 Spencer Osborne      30.337381  2016.0  128.0
# 7     2017                 Spencer Osborne      30.337381  2015.0  157.0
# 8     2017              Mary Jane Fountain      23.214286     NaN    NaN
# 9     2017                      Matt Hogan      23.123439     NaN    NaN
# 10    2017                   Colin Ferrian      22.635135     NaN    NaN
# 11    2017                     DX2 Capital      22.303082     NaN    NaN
# ...

# %%
topstocks30 = perfect30[['Author','Ticker','Day30Movement']].sort_values('Day30Movement',ascending = False).head(10)

# %%
perfect180.Day180Movement = perfect180.Day180Movement.astype(float)
# Out:
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
top180 = perfect180.groupby(['Year','Author'],as_index = False).Day180Movement.mean().sort_values(['Year','Day180Movement'], ascending = False).groupby('Year').head(10)

# %%
stock_count_year = seekingalpha.groupby((['Year', 'Stock']), as_index = False).Date.agg('count').sort_values(['Year','Date'],ascending = False).groupby('Year').head(5)

# %%
stock_count_year

# %%
grid = sns.FacetGrid(stock_count_year, row="Year", col="Date", hue = 'Stock')
grid.map(plt.hist, "Stock", color="steelblue", bins=bins, lw=0)

# %%
stock_count_year
# Out:
#       Year                          Stock  Date
# 8348  2017             The Boeing Company   123
# 7446  2017                     Apple Inc.    85
# 7400  2017               Amazon.com, Inc.    63
# 8029  2017           MannKind Corporation    51
# 7863  2017          Gilead Sciences, Inc.    49
# 6020  2016                     Apple Inc.    98
# 7088  2016             The Boeing Company    91
# 6096  2016    Bank of America Corporation    67
# 5970  2016               Amazon.com, Inc.    62
# 6240  2016  Chesapeake Energy Corporation    52
# 4033  2015                     Apple Inc.    76
# 4048  2015    Arena Pharmaceuticals, Inc.    68
# 5199  2015    Orexigen Therapeutics, Inc.    52
# 3974  2015               Amazon.com, Inc.    51
# 5056  2015         McDonald's Corporation    48
# 2461  2014                     Apple Inc.   127
# 2415  2014               Amazon.com, Inc.    63
# 3614  2014                   Tesla Motors    47
# 2536  2014    Bank of America Corporation    46
# ...

# %%
sns.kdeplot(seekingalpha['Year'], shade=True, label='Website Usage')

# %%
plt.plot(list(Month_breakdown.index),Month_breakdown.Date)

# %%
stock_count_year
# Out:
#       Year                          Stock  Date
# 8348  2017             The Boeing Company   123
# 7446  2017                     Apple Inc.    85
# 7400  2017               Amazon.com, Inc.    63
# 8029  2017           MannKind Corporation    51
# 7863  2017          Gilead Sciences, Inc.    49
# 6020  2016                     Apple Inc.    98
# 7088  2016             The Boeing Company    91
# 6096  2016    Bank of America Corporation    67
# 5970  2016               Amazon.com, Inc.    62
# 6240  2016  Chesapeake Energy Corporation    52
# 4033  2015                     Apple Inc.    76
# 4048  2015    Arena Pharmaceuticals, Inc.    68
# 5199  2015    Orexigen Therapeutics, Inc.    52
# 3974  2015               Amazon.com, Inc.    51
# 5056  2015         McDonald's Corporation    48
# 2461  2014                     Apple Inc.   127
# 2415  2014               Amazon.com, Inc.    63
# 3614  2014                   Tesla Motors    47
# 2536  2014    Bank of America Corporation    46
# ...

# %%
stock_count_year.Date = stock_count_year.Date.astype(str)
stock_count_year.Year = stock_count_year.Year.astype(str)
stock_count_year.Stock = stock_count_year.Stock.astype(str)

# %%
g = sns.FacetGrid(stock_count_year, col='Year', hue = 'Year', palette = "Set1", size = 4)
g.map(sns.distplot, 'Stock', 'Date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-541-570e8e7d4a36> in <module>()
#       1 g = sns.FacetGrid(stock_count_year, col='Year', hue = 'Year', palette = "Set1", size = 4)
# ----> 2 g.map(sns.distplot, 'Stock', 'Date')
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     726
#     727             # Draw the plot
# --> 728             self._facet_plot(func, ax, plot_args, kwargs)
#     729
#     730         # Finalize the annotations and layout
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     810
#     811         # Draw the plot
# --> 812         func(*plot_args, **plot_kwargs)
#     813
#     814         # Sort out the supporting information
#
# ...

# %%
stock_count_year.head()
# Out:
#       Year                  Stock   Date
# 8348  2017     The Boeing Company  123.0
# 7446  2017             Apple Inc.   85.0
# 7400  2017       Amazon.com, Inc.   63.0
# 8029  2017   MannKind Corporation   51.0
# 7863  2017  Gilead Sciences, Inc.   49.0

# %%
g.map(sns.barplot, 'Stock', 'Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-519-5ede9901d6ab> in <module>()
# ----> 1 g.map(sns.barplot, 'Stock', 'Date')
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     701
#     702             # Get the current axis
# --> 703             ax = self.facet_axis(row_i, col_j)
#     704
#     705             # Decide what color to plot with
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/seaborn/axisgrid.py in facet_axis(self, row_i, col_j)
#     832
#     833         # Get a reference to the axes object we want, and make it active
# --> 834         plt.sca(ax)
#     835         return ax
#     836
#
# /Users/FlexLex/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in sca(ax)
#     927             m.canvas.figure.sca(ax)
# ...

# %%
top5_author_count
# Out:
#       Year                     Author  Title
# 4957  2017          Zach Hartman, PhD    161
# 4283  2017             Dhierin Bechai    117
# 4519  2017             Kanak Kanti De     97
# 4928  2017            Vladimir Zernov     93
# 4183  2017                Bret Jensen     72
# 4451  2017                James Sands     72
# 4819  2017            Spencer Osborne     57
# 4883  2017         The Value Investor     47
# 4444  2017                 JD Henning     38
# 4089  2017            Activist Stocks     36
# 3154  2016          Achilles Research    140
# 3906  2016            Spencer Osborne    128
# 4034  2016            Vladimir Zernov    110
# 3359  2016             Dhierin Bechai     94
# 3468  2016             General Expert     65
# 3802  2016                Quinn Foley     54
# 3552  2016                James Sands     53
# 3887  2016             Shock Exchange     53
# 3974  2016         The Value Investor     51
# 3320  2016      D.M. Martins Research     48
# ...

# %%
grid = sns.FacetGrid(top5_author_count, col="Year")
sn

# %%
topstocks30
# Out:
#                   Author Ticker  Day30Movement
# 4770     Spencer Osborne   OREX     935.000000
# 8905        Equity Watch    BTU     747.663551
# 5014     Spencer Osborne   OREX     637.240076
# 1191   Zach Hartman, PhD   AVEO     254.437616
# 14488     Shock Exchange    ESI     141.866029
# 6530     Vladimir Zernov   SDRL     115.517241
# 11776         Lester Goh   BLDR     104.724409
# 1732     Spencer Osborne   MNKD     103.109328
# 15092        Bret Jensen   AVNR     101.032702
# 22905   LifeSci Advisors   ACAD      97.826087

# %%
top180
# Out:
#       Year                          Author  Day180Movement
# 1865  2017                 Vladimir Zernov     1421.790210
# 1856  2017                 Spencer Osborne      343.925234
# 1807  2017                    Bram de Haas      109.248555
# 1813  2017                   Colin Ferrian       65.775401
# 1810  2017                Bruce Vanderveen       55.346050
# 1852  2017                  Shock Exchange       53.894737
# 1836  2017                 Kenra Investors       53.433440
# 1854  2017              Slingshot Insights       53.033268
# 1855  2017              Societe Financiers       49.638610
# 1834  2017                   Josh Kolodner       46.632050
# 1653  2016                 Nader Hashemian      371.518987
# 1464  2016  Courage & Conviction Investing      188.947368
# 1408  2016                     Alpha World      122.550291
# 1688  2016         Reality Shares Research      116.783217
# 1590  2016                      Kal Telage      107.480625
# ...
